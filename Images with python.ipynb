# %%
# images with pillow

# %%
from PIL import Image

# %%
nepal = Image.open('example.jpg')

# %%
nepal.size
# Out:
# (300, 168)

# %%
# cropping

# %%
nepal.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
maala = Image.open('example2.jpg')

# %%
maala
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
maala.size
# Out:
# (275, 183)

# %%
rara = Image.open('example3.jpg')

# %%
rara
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=276x183>

# %%
# Exercise

# %%
maala.size
# Out:
# (275, 183)

# %%
rara.size
# Out:
# (276, 183)
